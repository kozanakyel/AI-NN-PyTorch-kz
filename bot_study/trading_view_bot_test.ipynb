# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from stockstats import StockDataFrame
import yfinance as yf

# %%
data = yf.download('ASELS.IS', start="2021-08-01", end="2022-08-22")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = pd.DataFrame(data)
df.columns= df.columns.str.lower()
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (20, 10)

# %%
df.shape
# Out:
# (266, 6)

# %%
aselsan = StockDataFrame(df)

# %%
aselsan[['close_50_sma','close_10_sma', 'close_20_ema', 'close_5_ema', 'close_10_ema', 'rsi_3', 'rsi_14','macd', 'dma']]
# aselsan = aselsan.dropna()
# Out:
#             close_50_sma  close_10_sma  close_20_ema  close_5_ema  \
# Date
# 2021-08-02     16.040001     16.040001     16.040001    16.040001
# 2021-08-03     16.110001     16.110001     16.113501    16.124001
# 2021-08-04     16.033334     16.033334     16.027761    16.008421
# 2021-08-05     16.035001     16.035001     16.031294    16.021539
# 2021-08-06     16.022001     16.022001     16.016468    16.001754
# ...                  ...           ...           ...          ...
# 2022-08-15     23.138800     23.794000     23.406041    24.217682
# 2022-08-16     23.122800     23.926000     23.466418    24.158455
# 2022-08-17     23.132800     24.090000     23.597236    24.385637
# 2022-08-18     23.154800     24.344000     23.818451    24.897091
# 2022-08-19     23.173200     24.542000     23.982408    25.111394
#
#             close_10_ema       rsi_3      rsi_14      macd     dma
# Date
# 2021-08-02     16.040001         NaN         NaN  0.000000  0.0000
# 2021-08-03     16.117001  100.000000  100.000000  0.003141  0.0000
# 2021-08-04     16.021728   23.728723   30.232453 -0.005301  0.0000
# 2021-08-05     16.027748   52.631623   50.191579 -0.003234  0.0000
# 2021-08-06     16.011170   42.149601   44.229900 -0.004828  0.0000
# ...                  ...         ...         ...       ...     ...
# 2022-08-15     23.842236   80.106501   66.487538  0.418419  0.6552
# 2022-08-16     23.878193   39.197782   59.442798  0.412947  0.8032
# 2022-08-17     24.053067   75.274487   66.683914  0.467772  0.9572
# 2022-08-18     24.392510   88.768916   73.549659  0.591549  1.1892
# 2022-08-19     24.601144   68.917592   68.222395  0.651470  1.3688
#
# [266 rows x 9 columns]

# %%
aselsan
# Out:
#                  open       high        low      close  adj close     volume  \
# Date
# 2021-08-02  15.560000  16.059999  15.550000  16.040001  15.889033   50427102
# 2021-08-03  16.010000  16.180000  15.860000  16.180000  16.027716   45150155
# 2021-08-04  16.180000  16.200001  15.850000  15.880000  15.730538   17946924
# 2021-08-05  15.800000  16.120001  15.780000  16.040001  15.889033   21874284
# 2021-08-06  16.000000  16.110001  15.830000  15.970000  15.819692   14220213
# ...               ...        ...        ...        ...        ...        ...
# 2022-08-15  24.799999  25.000000  24.420000  24.459999  24.459999   47563041
# 2022-08-16  24.540001  24.600000  23.280001  24.040001  24.040001   59393505
# 2022-08-17  24.200001  24.879999  24.100000  24.840000  24.840000   71978821
# 2022-08-18  25.040001  25.959999  24.500000  25.920000  25.920000  142618407
# 2022-08-19  26.080000  26.280001  25.379999  25.540001  25.540001   68471237
#
#             close_50_sma  close_10_sma  close_20_ema  close_5_ema  \
# Date
# 2021-08-02     16.040001     16.040001     16.040001    16.040001
# 2021-08-03     16.110001     16.110001     16.113501    16.124001
# 2021-08-04     16.033334     16.033334     16.027761    16.008421
# 2021-08-05     16.035001     16.035001     16.031294    16.021539
# 2021-08-06     16.022001     16.022001     16.016468    16.001754
# ...                  ...           ...           ...          ...
# 2022-08-15     23.138800     23.794000     23.406041    24.217682
# 2022-08-16     23.122800     23.926000     23.466418    24.158455
# 2022-08-17     23.132800     24.090000     23.597236    24.385637
# 2022-08-18     23.154800     24.344000     23.818451    24.897091
# 2022-08-19     23.173200     24.542000     23.982408    25.111394
#
#             close_10_ema      rs_3       rsi_3     rs_14      rsi_14  \
# Date
# 2021-08-02     16.040001       NaN         NaN       NaN         NaN
# 2021-08-03     16.117001       inf  100.000000       inf  100.000000
# 2021-08-04     16.021728  0.311110   23.728723  0.433331   30.232453
# 2021-08-05     16.027748  1.111113   52.631623  1.007693   50.191579
# 2021-08-06     16.011170  0.728597   42.149601  0.793075   44.229900
# ...                  ...       ...         ...       ...         ...
# 2022-08-15     23.842236  4.026768   80.106501  1.983965   66.487538
# 2022-08-16     23.878193  0.644677   39.197782  1.465653   59.442798
# 2022-08-17     24.053067  3.044405   75.274487  2.001553   66.683914
# 2022-08-18     24.392510  7.903860   88.768916  2.780670   73.549659
# 2022-08-19     24.601144  2.217254   68.917592  2.146870   68.222395
#
#                 macd     macds     macdh     dma
# Date
# 2021-08-02  0.000000  0.000000  0.000000  0.0000
# 2021-08-03  0.003141  0.001745  0.001396  0.0000
# 2021-08-04 -0.005301 -0.001143 -0.004158  0.0000
# 2021-08-05 -0.003234 -0.001851 -0.001383  0.0000
# 2021-08-06 -0.004828 -0.002736 -0.002091  0.0000
# ...              ...       ...       ...     ...
# 2022-08-15  0.418419  0.197279  0.221140  0.6552
# 2022-08-16  0.412947  0.240412  0.172535  0.8032
# 2022-08-17  0.467772  0.285884  0.181888  0.9572
# 2022-08-18  0.591549  0.347017  0.244532  1.1892
# 2022-08-19  0.651470  0.407908  0.243563  1.3688
#
# [266 rows x 19 columns]

# %%
buy_signals1 = aselsan['close_10_ema_xd_close_5_ema']

# %%
for i in range(len(buy_signals1)):
    if aselsan['close_5_ema'].iloc[i] >= aselsan['close_10_ema'].iloc[i] \
            and aselsan['close_20_ema'].iloc[i] >= aselsan['close_50_sma'].iloc[i] \
        and aselsan['close_10_sma'].iloc[i] <= aselsan.close[i] \
            and aselsan['rsi_3'].iloc[i] > aselsan['rsi_14'].iloc[i] \
                and aselsan['macdh'].iloc[i] > aselsan['macds'].iloc[i]:
        buy_signals1.iloc[i] = aselsan.close[i]
    else:
        buy_signals1.iloc[i] = np.nan
# Out:
# /tmp/ipykernel_165/1128015379.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buy_signals1.iloc[i] = np.nan

# %%
buy_signals1
# Out:
# Date
# 2021-08-02          NaN
# 2021-08-03          NaN
# 2021-08-04          NaN
# 2021-08-05          NaN
# 2021-08-06          NaN
#                 ...
# 2022-08-15    24.459999
# 2022-08-16          NaN
# 2022-08-17          NaN
# 2022-08-18          NaN
# 2022-08-19          NaN
# Name: close_10_ema_xd_close_5_ema, Length: 266, dtype: object

# %%
plt.plot(aselsan['close'], linewidth=2.5, label='ASELSAN')
plt.plot(aselsan['close_10_sma'], linewidth=2.5, alpha=0.6, label='SMA 10')
plt.plot(aselsan['close_50_sma'], linewidth=2.5, alpha=0.6, label='SMA 50')
plt.plot(aselsan['close_20_ema'], linewidth=2.5, alpha=0.6, label='EMA 20')
plt.plot(aselsan['close_10_ema'], linewidth=2.5, alpha=0.6, label='EMA 10')
plt.plot(aselsan['close_5_ema'], linewidth=2.5, alpha=0.6, label='EMA 5')
plt.plot(aselsan.index, buy_signals1, marker='^', markersize=15, color='green', linewidth=0, label='BUY SIGNAL')
plt.legend(loc='upper left')
plt.title('ASELSAN Trading View Strategy')
plt.show()
